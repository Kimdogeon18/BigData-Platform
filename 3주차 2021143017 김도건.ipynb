# %%
tuple1 = ('Red','Green','Blue')
tuple2 = tuple([5,6,7,8])
tuple3=tuple1+tuple2
print(tuple3)
# Out:
# ('Red', 'Green', 'Blue', 5, 6, 7, 8)

# %%
tuple4=tuple2*3

# %%
tuple4
# Out:
# [5, 6, 7, 8, 5, 6, 7, 8, 5, 6, 7, 8]

# %%
len(tuple1)
# Out:
# 3

# %%
max(tuple2)
# Out:
# 8

# %%
min(tuple2)
# Out:
# 5

# %%
sum(tuple2)
# Out:
# 26

# %%
import pandas as pd

# %%
stdData = [ ['Kim', 23, '하남시'],
            ['lee', 28, '의왕시'],
            ['kang', 21, '부천시'],
            ['hong', 18, '서울시'],
          ]

# %%
stdData
# Out:
# [['Kim', 23, '하남시'],
#  ['lee', 28, '의왕시'],
#  ['kang', 21, '부천시'],
#  ['hong', 18, '서울시']]

# %%
df = pd.DataFrame(stdData)

# %%
df
# Out:
#       0   1    2
# 0   Kim  23  하남시
# 1   lee  28  의왕시
# 2  kang  21  부천시
# 3  hong  18  서울시

# %%
이름 = ['kim','lee','park','choi']
나이 = [20,25,19,16]
주소 = ['서울시', ' 경기도' , '제주도', '전라도']

# %%
df = pd.DataFrame( {'name':이름, 'age':나이, 'addr':주소} )
df
# Out:
#    name  age  addr
# 0   kim   20   서울시
# 1   lee   25   경기도
# 2  park   19   제주도
# 3  choi   16   전라도

# %%
df = pd.read_csv('test.txt')
df
# Out:
#     이름          학번        학과
# 0  김도건  2021143017  AI소프트웨어과
# 1  김석윤  2021143018  AI소프트웨어과
# 2  홍도영  2021143019  AI소프트웨어과
# 3  강태현  2021143020  AI소프트웨어과

# %%
ca = pd.read_excel('data_연도별출생인구.xlsx')
ca
# Out:
#       연도    출생아수  천명당출생률
# 0   1951  728175    37.7
# 1   1952  775630    39.6
# 2   1953  830330    41.6
# 3   1954  892236    43.4
# 4   1955  961055    45.4
# ..   ...     ...     ...
# 63  2014  435435     8.6
# 64  2015  438420     8.6
# 65  2016  406243     7.9
# 66  2017  357771     7.0
# 67  2018  326900     6.4
#
# [68 rows x 3 columns]

# %%
df = pd.read_csv('exam1.txt')
df
# Out:
#    name   score   absent
# 0   kim      95         3
# 1  choi     100         0
# 2   lee      90         2
# 3  park      85         1
# 4   cho      77         5

# %%
df = pd.read_csv('exam2.txt',delimiter='\t')
df
# Out:
#    name  score  absent
# 0   kim     95        3
# 1  choi    100        0
# 2   lee     90        2
# 3  park     85        1
# 4   cho     77        5

# %%
df = pd.read_csv('exam.txt',header=None)
df
# Out:
#       0    1  2
# 0   kim   95  3
# 1  choi  100  0
# 2   lee   90  2
# 3  park   85  1
# 4   cho   77  5

# %%
df = pd.read_csv('exam4.csv',encoding='EUC-KR')
df
# Out:
#      연도     출생아수     사망자수
# 0  2011  471,265  257,396
# 1  2012  484,550  267,221
# 2  2013  436,455  266,257
# 3  2014  435,435  267,692
# 4  2015  438,420  275,895
# 5  2016  406,243  280,827
# 6  2017  357,771  285,534
# 7  2018  326,900  298,820

# %%
ca = pd.read_excel('data_연도별출생인구.xlsx')
ca
# Out:
#       연도    출생아수  천명당출생률
# 0   1951  728175    37.7
# 1   1952  775630    39.6
# 2   1953  830330    41.6
# 3   1954  892236    43.4
# 4   1955  961055    45.4
# ..   ...     ...     ...
# 63  2014  435435     8.6
# 64  2015  438420     8.6
# 65  2016  406243     7.9
# 66  2017  357771     7.0
# 67  2018  326900     6.4
#
# [68 rows x 3 columns]

# %%
ca.head(20)
# Out:
#       연도     출생아수  천명당출생률
# 0   1951   728175    37.7
# 1   1952   775630    39.6
# 2   1953   830330    41.6
# 3   1954   892236    43.4
# 4   1955   961055    45.4
# 5   1956   999005    45.2
# 6   1957  1016573    44.8
# 7   1958  1046011    44.5
# 8   1959  1074876    44.2
# 9   1960  1099294    44.0
# 10  1961  1099164    42.7
# 11  1962  1089951    41.1
# 12  1963  1075203    39.4
# 13  1964  1057241    37.8
# 14  1965  1040544    36.3
# 15  1966  1028479    34.9
# 16  1967  1020235    33.9
# 17  1968  1016739    33.0
# 18  1969  1017618    32.3
# 19  1970  1006645    31.2

# %%
ca.tail(20)
# Out:
#       연도    출생아수  천명당출생률
# 48  1999  614233    13.0
# 49  2000  634501    13.3
# 50  2001  554895    11.6
# 51  2002  492111    10.2
# 52  2003  490543    10.2
# 53  2004  472761     9.8
# 54  2005  435031     8.9
# 55  2006  448153     9.2
# 56  2007  493189    10.0
# 57  2008  465892     9.4
# 58  2009  444849     9.0
# 59  2010  470171     9.4
# 60  2011  471265     9.4
# 61  2012  484550     9.6
# 62  2013  436455     8.6
# 63  2014  435435     8.6
# 64  2015  438420     8.6
# 65  2016  406243     7.9
# 66  2017  357771     7.0
# 67  2018  326900     6.4

# %%
ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      68 non-null     int64
#  1   출생아수    68 non-null     int64
#  2   천명당출생률  68 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 1.7 KB

# %%
ca.describe()
# Out:
#                연도          출생아수     천명당출생률
# count    68.00000  6.800000e+01  68.000000
# mean   1984.50000  7.451443e+05  22.483824
# std      19.77372  2.271235e+05  12.619395
# min    1951.00000  3.269000e+05   6.400000
# 25%    1967.75000  5.394685e+05  11.250000
# 50%    1984.50000  7.246800e+05  16.700000
# 75%    2001.25000  9.621715e+05  33.225000
# max    2018.00000  1.099294e+06  45.400000

# %%
ca[0:3]
# Out:
#      연도    출생아수  천명당출생률
# 0  1951  728175    37.7
# 1  1952  775630    39.6
# 2  1953  830330    41.6

# %%
ca[:13]
# Out:
#       연도     출생아수  천명당출생률
# 0   1951   728175    37.7
# 1   1952   775630    39.6
# 2   1953   830330    41.6
# 3   1954   892236    43.4
# 4   1955   961055    45.4
# 5   1956   999005    45.2
# 6   1957  1016573    44.8
# 7   1958  1046011    44.5
# 8   1959  1074876    44.2
# 9   1960  1099294    44.0
# 10  1961  1099164    42.7
# 11  1962  1089951    41.1
# 12  1963  1075203    39.4

# %%
ca['연도']
# Out:
# 0     1951
# 1     1952
# 2     1953
# 3     1954
# 4     1955
#       ...
# 63    2014
# 64    2015
# 65    2016
# 66    2017
# 67    2018
# Name: 연도, Length: 68, dtype: int64

# %%
ca['천명당출생률']
# Out:
# 0     37.7
# 1     39.6
# 2     41.6
# 3     43.4
# 4     45.4
#       ...
# 63     8.6
# 64     8.6
# 65     7.9
# 66     7.0
# 67     6.4
# Name: 천명당출생률, Length: 68, dtype: float64

# %%
ca.출생아수
# Out:
# 0     728175
# 1     775630
# 2     830330
# 3     892236
# 4     961055
#        ...
# 63    435435
# 64    438420
# 65    406243
# 66    357771
# 67    326900
# Name: 출생아수, Length: 68, dtype: int64

# %%
data1950=ca[0:9]
data1950
# Out:
#      연도     출생아수  천명당출생률
# 0  1951   728175    37.7
# 1  1952   775630    39.6
# 2  1953   830330    41.6
# 3  1954   892236    43.4
# 4  1955   961055    45.4
# 5  1956   999005    45.2
# 6  1957  1016573    44.8
# 7  1958  1046011    44.5
# 8  1959  1074876    44.2

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data1950['출생아수'],marker='o')
#plt.ylim(600_000, 1_200_000)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = df[29:50] .출생아수
# Out:
# Series([], Name: 출생아수, dtype: object)

# %%
data = ca[29:50] .출생아수
plt.plot( data, marker='o')
plt.grid()
#plt.ylim(600_000, 1_200_000)
plt.show()
