# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp1994 = [39.6, 37.9, 37.9, 34.9,
33.9, 35.3, 35.9, 35.3, 32.5, 36.8]

temp2018 = [29.3, 33.9, 32.5, 32.4,
35.6, 35.9, 33.6, 33.8, 37.0, 29.3]

# %%
plt.plot( temp1994, marker='^', label='1994')
plt.plot( temp2018, marker='o', label='2018')

plt.legend()
plt.show()

# %%
temp1994 = [39.6, 37.9, 37.9, 34.9,
33.9, 35.3, 35.9, 35.3, 32.5, 36.8]

temp2018 = [29.3, 33.9, 32.5, 32.4,
35.6, 35.9, 33.6, 33.8, 37.0, 29.3]


plt.plot( temp1994, marker='^', label='1994')
plt.plot( temp2018, marker='o', label='2018')

plt.ylim(20,45)

plt.legend()
plt.show()

# %%
temp1994 = [39.6, 37.9, 37.9, 34.9,
33.9, 35.3, 35.9, 35.3, 32.5, 36.8]

temp2018 = [29.3, 33.9, 32.5, 32.4,
35.6, 35.9, 33.6, 33.8, 37.0, 29.3]


plt.plot( temp1994, marker='^', label='1994')
plt.plot( temp2018, marker='o', label='2018')

plt.ylim(20,45)
plt.xlim(0,9)

plt.legend()
plt.show()

# %%
temp1994 = [39.6, 37.9, 37.9, 34.9,
33.9, 35.3, 35.9, 35.3, 32.5, 36.8]

temp2018 = [29.3, 33.9, 32.5, 32.4,
35.6, 35.9, 33.6, 33.8, 37.0, 29.3]


plt.plot( temp1994, marker='^', label='1994')
plt.plot( temp2018, marker='o', label='2018')
plt.legend()
plt.ylim(20,45)
plt.xlim(2,8)

plt.title('tempaeature')
plt.show()

# %%
temp1994 = [39.6, 37.9, 37.9, 34.9,
33.9, 35.3, 35.9, 35.3, 32.5, 36.8]

temp2018 = [29.3, 33.9, 32.5, 32.4,
35.6, 35.9, 33.6, 33.8, 37.0, 29.3]


plt.plot( temp1994, marker='^', label='1994')
plt.plot( temp2018, marker='o', label='2018')
plt.legend()
plt.ylim(20,45)

plt.rc('font', family='Malgun Gothic')
plt.title('최고 기온 비교')

plt.show()

# %%
temp1994 = [39.6, 37.9, 37.9, 34.9,
33.9, 35.3, 35.9, 35.3, 32.5, 36.8]

temp2018 = [29.3, 33.9, 32.5, 32.4,
35.6, 35.9, 33.6, 33.8, 37.0, 29.3]


plt.plot( temp1994, marker='^', label='1994')
plt.plot( temp2018, marker='o', label='2018')
plt.legend()
plt.ylim(20,45)

plt.rc('font', family='Malgun Gothic')
plt.title('최고 기온 비교')

plt.grid(True)

plt.show()

# %%
temp1994 = [39.6, 37.9, 37.9, 34.9,
33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4,
35.6, 35.9, 33.6, 33.8, 37.0, 29.3]
plt.plot( temp1994, marker='^', label='1994')
plt.plot( temp2018, marker='o', label='2018')
plt.legend()
plt.ylim(20,45)
plt.rc('font', family='Malgun Gothic')
plt.title('최고 기온 비교')
plt.grid(True)

plt.xlabel('날짜 변화')
plt.ylabel('최고 기온')

plt.show()

# %%
temp1994 = [39.6, 37.9, 37.9, 34.9,
33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4,
35.6, 35.9, 33.6, 33.8, 37.0, 29.3]
plt.plot( temp1994, marker='^', label='1994')
plt.plot( temp2018, marker='o', label='2018')
plt.legend()
plt.ylim(20,45)
plt.rc('font', family='Malgun Gothic')
plt.title('최고 기온 비교')
plt.grid(True)

plt.xlabel('날짜 변화')
plt.ylabel('최고 기온')

plt.xticks( np.arange(0, 10, 0.5))

plt.show()

# %%
temp1994 = [39.6, 37.9, 37.9, 34.9,
33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4,
35.6, 35.9, 33.6, 33.8, 37.0, 29.3]
plt.plot( temp1994, marker='^', label='1994')
plt.plot( temp2018, marker='o', label='2018')
plt.legend()
plt.ylim(20,45)
plt.rc('font', family='Malgun Gothic')
plt.title('최고 기온 비교')
plt.grid(True)

plt.xlabel('날짜 변화')
plt.ylabel('최고 기온')

# plt.xticks( np.arange(0, 10, 0.5))
plt.xticks( np.arange(10), ('1일','2일','3일','4일','5일','6일','7일','8일','9일','10일'))
plt.show()

# %%
temp1994 = [39.6, 37.9, 37.9, 34.9,
33.9, 35.3, 35.9, 35.3, 32.5, 36.8]
temp2018 = [29.3, 33.9, 32.5, 32.4,
35.6, 35.9, 33.6, 33.8, 37.0, 29.3]
plt.plot( temp1994, marker='^', label='1994')
plt.plot( temp2018, marker='o', label='2018')
plt.legend()
plt.ylim(25,42)
plt.rc('font', family='Malgun Gothic')
plt.title('최고 기온 비교')
plt.grid(True)

plt.xlabel('날짜 변화')
plt.ylabel('최고 기온')

# plt.xticks( np.arange(0, 10, 0.5))
plt.xticks( np.arange(10), ('1일','2일','3일','4일','5일','6일','7일','8일','9일','10일'))
plt.yticks( np.arange(25, 42, 2))
plt.show()

# %%
import matplotlib.pyplot as plt

xValues = [1,2,3,4]
yValues = [10,30,20,40]

plt.plot(xValues, yValues)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,30,20,40]

plt.plot( x, y, marker='o')
plt.xticks([1,2,3,4])
plt.show()

# %%
import matplotlib.pyplot as plt

xValues = [1,2,3,4]
yValues = [3,5,6,7]

plt.scatter(xValues, yValues)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xVal = np.random.randint(0, 50,20)
yVal = np.random.randint(0,50,20)

plt.scatter(xVal, yVal)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xVal = np.random.randint(0,50,20)
yVal = np.random.randint(0,50,20)
colors = np.random.randint(0,20,20)
sizes = np.random.randint(5,20,20)*5

plt.scatter(xVal, yVal, c=colors, s=sizes)
plt.show()
